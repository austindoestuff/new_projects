# %%
import deep_daze
from deep_daze import Imagine

imagine = Imagine(
    text = 'random',
    num_layers = 24,
    image_width=256,
    batch_size=1,
)
imagine()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-19-1e39fcd00c8a> in <module>
#       2 from deep_daze import Imagine
#       3
# ----> 4 imagine = Imagine(
#       5     text = 'random',
#       6     num_layers = 24,
#
# ~/anaconda3/lib/python3.8/site-packages/deep_daze/deep_daze.py in __init__(self, text, img, clip_encoding, lr, batch_size, gradient_accumulate_every, save_every, image_width, num_layers, epochs, iterations, save_progress, seed, open_folder, save_date_time, start_image_path, start_image_train_iters, start_image_lr, theta_initial, theta_hidden, lower_bound_cutout, upper_bound_cutout, saturate_bound, create_story, story_start_words, story_words_per_epoch, save_gif)
#     272         # create coding to optimize for
#     273         self.clip_img_transform = create_clip_img_transform(224)
# ...
